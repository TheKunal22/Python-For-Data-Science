# %% [markdown]
# # **Seaborn**

# %% [markdown]
# # **Distribution Plots**
#
# - distplot
# - joinplot : whenever we have 2 feature then we  will use this to see the 2d plot
# - pairplot : whenever we have more than than 2 feature then we will use this
#
# practice problem on IRIS Dataset

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df.head() # here tip is actually depenedent feature and total bill , sex , smoker etc are inde 

''' if the values are categorical feature then we are not able to find out the correlation 
becuase we know that categorical feature are object type whereas all the other frature 
are int and float type .'''
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# whenever we have one feature f1 then it would be called univariate analysis
# and whenever we have two feature f1 and f2 then it would be called bivariate analysis this f1 and f2 togehter would make a 2d and if f1,f2,f3 3 features then it would make 3d but if 4 then we are not able to see the 4d because as a human we can only see till the 3d

# %%
df.dtypes ''' as sir told ki feature value agar int and float hue tabhi apn correlation find kar paige 
and yaha p feature values apni total_bill , tip and size h so thats why we are able to 
find the correlation '''

'''why are we calling totatl bill and tip and size feature ??

becuase these characters are helping us to get the outcome so thats why they are features 
for us for getting outcome '''
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# # coorelation with heatmap
#
# A coorelation heatmap uses colored cells , typically in a monocrhomatic scale , to show
# a 2d correalation matrix (table) between two discrete dimensions or event types. it is very important in feature solution

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.corr()
#
# File D:\Anaconda\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File D:\Anaconda\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %% [markdown]
# # Assistant
# This error occurs because the `corr()` function is trying to calculate correlations between columns, but it encountered string values (specifically 'No') that it cannot convert to numerical values for correlation calculations.
#
# The error message "ValueError could not convert string to float: 'No'" indicates that your DataFrame contains string values like 'No' in columns where numerical values are expected for correlation calculations.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # User
# yes

# %%
# Assistant
# First, let's examine which columns contain string values
print(df.dtypes)

# Option 1: Convert categorical variables to numeric
# For binary variables like Yes/No
df_numeric = df.copy()
# Replace 'No' with 0 and 'Yes' with 1 in all columns (adjust as needed)
df_numeric = df_numeric.replace({'No': 0, 'Yes': 1})

# Option 2: Calculate correlation only for numeric columns
# This automatically excludes non-numeric columns
numeric_df = df.select_dtypes(include=['number'])
correlation = numeric_df.corr()

# Display the correlation matrix
correlation
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9168\1192625331.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_numeric = df_numeric.replace({'No': 0, 'Yes': 1})
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9168\1192625331.py:9: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df_numeric = df_numeric.replace({'No': 0, 'Yes': 1})
# ...

# %% [markdown]
# correlation is (+) means they are directly proportional
#                      correlation is (-) means they are inversely proportional

# %%
sns.heatmap(correlation)
# Out:
# <Axes: >

# %% [markdown]
# # JoinPlot
#
# A join plot allows to study the realationship between 2 numeric variables . the central chart display their correlation . the central chart display their correlation . it is usually a scatterplot , a hexbin plot , a 2D histogram or a 2D density plot

# %% [markdown]
# # **Univariate Analysis**

# %%
sns.jointplot(x='tip' ,y='total_bill' , data = df , kind = 'hex' )

# %%
# instead of hex lets give reg  , here we have 2 feature
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg') # reg means regresssion here , regresssion line is displayed here .

# %% [markdown]
# # **pair plot**
#
# a pair plot is als o known as a scatter plot in which one variable in the same data row is matched with another variables value , like this : pairs plots are just elaboration on this , shwoing all variables paired with all the other variables .

# %%
sns.pairplot(df) # whenever we are plotting this kind of digragram we have to make sure features are int or float valuues

# %%
sns.pairplot(df , hue='sex')

# %%
sns.pairplot(df, hue='smoker')

# %% [markdown]
# # **Dist plot**
#
# dist plot helps us to check the distribution of the columns feature

# %%
sns.displot(df['tip'])

# %%
sns.displot(df['tip'] , kde=True , bins=10) # kernal density estimation

# %%
sns.displot(df['tip'] , kde=False , bins=10)

# %% [markdown]
# # **Categorical plots**
#
# seaborn also helps us in doing the analysis on categorical data points . in this section we will discuss about
#
# - boxplot
# - violinplot
# - countplot
# - bar plot

# %%
sns.countplot(x='sex',data=df) # check for others category too
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='day',data=df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
# count plot 
sns.countplot(y='sex',data=df)
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %% [markdown]
# in the count plot you just have to give one value x or y becaeuse the another one going
# to be count value but in bar plot case you will have to give the both values x and y

# %%
# Bar plot 
sns.barplot(x='total_bill',y='sex' , data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
# bar plot
sns.barplot(x='sex',y='total_bill' , data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ## **BOX PLOT**
# a box and whisker plot (sometimes called a boxplot) is a group that presents info from a five-number summary.

# %%
sns.boxplot(data=df , x='sex',y='total_bill' , palette='rainbow')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9168\1839067812.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df , x='sex',y='total_bill' , palette='rainbow')
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# just changing the x and y 
sns.boxplot(data=df , x='total_bill' ,y='sex', palette='rainbow')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9168\4054208968.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df , x='total_bill' ,y='sex', palette='rainbow')
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
sns.boxplot(data=df , x='day',y='total_bill' , palette='rainbow')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9168\393887605.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df , x='day',y='total_bill' , palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=df ,orient='v')
# Out:
# <Axes: >

# %%
# categorize my data based on some other categories .
sns.boxplot(data=df , x='total_bill' , y ='day' , hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# # **Violin Plot**
# Violin plot helps us to see both the distribution of data in terms of kernal density estimation and the box plot .

# %%
sns.violinplot(x='total_bill' , y='day' , data=df , palette='rainbow')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9168\1875085834.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='total_bill' , y='day' , data=df , palette='rainbow')
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# # **practice homework**

# %%
iris = sns.load_dataset('iris') # my suggestion dont see this just try to do this by your own . 
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
grouped = iris.groupby('species').mean(numeric_only=True)
sns.heatmap(grouped, annot=True)
# Out:
# <Axes: ylabel='species'>

# %%
sns.displot(grouped , x='sepal_length' , y = 'species'   , hue = 'species' , palette='rainbow')

# %%
grouped['sepal_length'].head() # lol apn yaha p grouped s joint plot m species ka hi compare kar rahe the sepal_length
# Out:
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal_length, dtype: float64

# %%
sns.jointplot( iris ,x='sepal_length' , y='sepal_width' ,  kind='hex')
# here we got the maximum speal width which 4.5 and which is a outlier

# %%
sns.jointplot(iris ,x='sepal_length',y='sepal_width', kind='scatter' )

# %%
sns.pairplot(iris)

# %%
sns.jointplot(iris , x='sepal_length',y='sepal_width' , kind='reg') # getting the regresssion line horizontally

'''sepal length is going up here as you can see and that means sepal width is going down in general trend right ????

🔍 What the Graph Shows
- As sepal length increases (moves right on the x-axis),
- Sepal width tends to decrease (moves down on the y-axis).
That’s called a negative correlation. The regression line (the slanted line through the dots) confirms this trend—it slopes downward.
📉 What That Means
In simple terms:
Longer sepals usually come with narrower widths.

This doesn’t mean every single flower follows that rule, but on average, that’s the pattern in the data.
'''

# %%
sns.pairplot(iris , hue='sepal_length')

# %%
sns.boxplot(iris , x='petal_length' , y='petal_width', palette='rainbow')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9168\4094111382.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(iris , x='petal_length' , y='petal_width', palette='rainbow')
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.violinplot(iris , x='sepal_length' , y='sepal_width' , palette='rainbow')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9168\1928184767.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(iris , x='sepal_length' , y='sepal_width' , palette='rainbow')
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.displot(iris , x='sepal_length' , y='sepal_width')

# %%
sns.displot(iris , x='sepal_length' , y='sepal_width')

# %%
sns.boxplot(iris ,  x='sepal_length' , y='sepal_width' , hue='species') # yaha p color species ko represent kar rha h
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.pairplot(iris , hue='species') # yaha p color species ko represent kar rha h jo ki sab s compare ho rha h  , ye dots species h and comparision is going on with each features .

# %%
sns.jointplot(iris)
